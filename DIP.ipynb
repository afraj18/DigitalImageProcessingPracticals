# %% [markdown]
# <a href="https://colab.research.google.com/github/afraj18/DigitalImageProcessingPracticals/blob/main/DIP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib.image import imread
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
AZpeppers = cv2.imread('/content/sample_data/peppers.png')
coins = cv2.imread('/content/sample_data/coins.png')

# %%
cv2_imshow(peppers)
plt.title("Peppers")
plt.imshow(peppers)
# Out:
# <PIL.Image.Image image mode=RGB size=512x384 at 0x7F34A7657AD0>

# %%
cv2_imshow(coins)
plt.title("Coins")
plt.imshow(coins)
# Out:
# <PIL.Image.Image image mode=RGB size=300x246 at 0x7F34A7693390>

# %%
[r,c,d] = peppers.shape
print("Resolution of peppers image : "+str(r)+"x"+str(c))
# Out:
# Resolution of peppers image : 384x512

# %%
[r,c,d] = coins.shape
print("Resolution of peppers image : "+str(r)+"x"+str(c))
# Out:
# Resolution of peppers image : 246x300

# %%
[r,c,d] = peppers.shape
print("Number of pixels in Pepper image : "+str(r*c))
# Out:
# Number of pixels in Pepper image : 196608

# %%
[r,c,d] = coins.shape
print("Number of pixels in Coins image : "+str(r*c))
# Out:
# Number of pixels in Coins image : 73800

# %%
plt.title("Coins")
plt.imshow(coins)

# %%
cv2_imshow(coins[1:100,1:50,:])
# Out:
# <PIL.Image.Image image mode=RGB size=49x99 at 0x7F34A755B610>

# %%
plt.title("Pepper")
plt.imshow(peppers)

# %%
cv2_imshow(peppers[230:320,410:520])
# Out:
# <PIL.Image.Image image mode=RGB size=102x90 at 0x7F34A77CE910>

# %%
print("Size of Peppers Image : "+str(peppers.size/8))
print("Size of Coins Image : "+str(coins.size/8))
# Out:
# Size of Peppers Image : 73728.0
# Size of Coins Image : 27675.0

# %%
peppers_gray = cv2.cvtColor(peppers,cv2.COLOR_BGR2GRAY)
cv2_imshow(peppers_gray)
# Out:
# <PIL.Image.Image image mode=L size=512x384 at 0x7F34A74EE050>

# %%
binary_coin = cv2.threshold(coins, 128, 255, cv2.THRESH_BINARY)[1]
cv2_imshow(binary_coin)
# Out:
# <PIL.Image.Image image mode=RGB size=300x246 at 0x7F34A7554A10>
